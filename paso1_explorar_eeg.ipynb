# %%
import mne
from mne.datasets import eegbci

archivos = eegbci.load_data(subjects=1, runs=[4])
raw = mne.io.read_raw_edf(archivos[0], preload=True)
print(raw.info)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import mne
#       2 from mne.datasets import eegbci
#       3
# ----> 4 archivos = eegbci.load_data(subject=1, runs=[4])
#       5 raw = mne.io.read_raw_edf(archivos[0], preload=True)
#       6 print(raw.info)
#
# TypeError: load_data() got an unexpected keyword argument 'subject'. Did you mean 'subjects'?
