# %%
import mne
from mne.datasets import eegbci

archivos = eegbci.load_data(subjects=1, runs=[4])
raw = mne.io.read_raw_edf(archivos[0], preload=True)
print(raw.info)
# Out:
# Extracting EDF parameters from /home/patrick/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S001/S001R04.edf...
# Using normal I/O
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Using normal I/O
# Using normal I/O
# Cropping annotations 1970-01-01 00:00:00+00:00 - 1970-01-01 00:02:05+00:00
#   [0] Keeping  (1970-01-01 00:00:00+00:00 - 1970-01-01 00:00:04.200000+00:00 -> 0.0 - 4.2)
#   [1] Keeping  (1970-01-01 00:00:04.200000+00:00 - 1970-01-01 00:00:08.300000+00:00 -> 4.2 - 8.3)
#   [2] Keeping  (1970-01-01 00:00:08.300000+00:00 - 1970-01-01 00:00:12.500000+00:00 -> 8.3 - 12.5)
#   [3] Keeping  (1970-01-01 00:00:12.500000+00:00 - 1970-01-01 00:00:16.600000+00:00 -> 12.5 - 16.6)
#   [4] Keeping  (1970-01-01 00:00:16.600000+00:00 - 1970-01-01 00:00:20.800000+00:00 -> 16.6 - 20.8)
#   [5] Keeping  (1970-01-01 00:00:20.800000+00:00 - 1970-01-01 00:00:24.900000+00:00 -> 20.8 - 24.9)
# ...

# %%
mne.set_log_level('WARNING')  # para que no tire tanto texto de debug
raw.plot(duration=5, n_channels=10)
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
print(raw.annotations)
# Out:
# <Annotations | 30 segments: T0 (15), T1 (8), T2 (7)>
